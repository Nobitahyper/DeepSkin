# %%
# Mount Google Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os
# Setting paths
TRAIN_IMAGE_PATH = "/content/drive/MyDrive/EfficientNet/ISBI2016_ISIC_Part1_Training_Data"
TRAIN_MASK_PATH = "/content/drive/MyDrive/EfficientNet/ISBI2016_ISIC_Part1_Training_GroundTruth"
TEST_IMAGE_PATH = "/content/drive/MyDrive/EfficientNet/ISBI2016_ISIC_Part1_Test_Data"
TEST_MASK_PATH = "/content/drive/MyDrive/EfficientNet/ISBI2016_ISIC_Part1_Test_GroundTruth"
# Get the list of training image and mask filenames
training_images = set(os.listdir(TRAIN_IMAGE_PATH))
training_masks = {mask_file.replace('_Segmentation.png', '.jpg') for mask_file in os.listdir(TRAIN_MASK_PATH)}

# Identify and print the unmatched training images
unmatched_training_images = training_images - training_masks
print("Unmatched training images:", unmatched_training_images)

# If you wish to remove the unmatched images, uncomment and run the following:
for image_file in unmatched_training_images:
     os.remove(os.path.join(TRAIN_IMAGE_PATH, image_file))
# Out:
# Unmatched training images: set()

# %%
import os
import numpy as np
from tensorflow.keras.preprocessing.image import load_img, img_to_array

# Setting paths
TRAIN_IMAGE_PATH = "/content/drive/MyDrive/EfficientNet/ISBI2016_ISIC_Part1_Training_Data"
TRAIN_MASK_PATH = "/content/drive/MyDrive/EfficientNet/ISBI2016_ISIC_Part1_Training_GroundTruth"
TEST_IMAGE_PATH = "/content/drive/MyDrive/EfficientNet/ISBI2016_ISIC_Part1_Test_Data"
TEST_MASK_PATH = "/content/drive/MyDrive/EfficientNet/ISBI2016_ISIC_Part1_Test_GroundTruth"

def custom_data_generator(image_dir, mask_dir, batch_size, image_size=(128, 128), shuffle=True, augment=False):
    # Fetch all the image and mask paths
    image_files = sorted([os.path.join(image_dir, file) for file in os.listdir(image_dir)])
    mask_files = sorted([os.path.join(mask_dir, file) for file in os.listdir(mask_dir)])

    total = len(image_files)
    indices = np.arange(total)

    while True:
        # Shuffle indices after each epoch
        if shuffle:
            np.random.shuffle(indices)

        for start in range(0, total, batch_size):
            end = min(start + batch_size, total)
            batch_indices = indices[start:end]

            batch_images = []
            batch_masks = []
            for i in batch_indices:
                # Load images and masks, then preprocess them
                img = load_img(image_files[i], target_size=image_size)
                img = img_to_array(img) / 255.0

                mask = load_img(mask_files[i], target_size=image_size, color_mode="grayscale")
                mask = img_to_array(mask) / 255.0

                batch_images.append(img)
                batch_masks.append(mask)

            yield np.array(batch_images), np.array(batch_masks)

# Create generators
train_generator = custom_data_generator(TRAIN_IMAGE_PATH, TRAIN_MASK_PATH, 32)
val_generator = custom_data_generator(TEST_IMAGE_PATH, TEST_MASK_PATH, 32, shuffle=False)

# %%
from tensorflow.keras.applications import EfficientNetB0
from tensorflow.keras.layers import Input, Conv2D, UpSampling2D, Concatenate
from tensorflow.keras.models import Model

input_shape = (128, 128, 3)
base_model = EfficientNetB0(include_top=False, weights="imagenet", input_shape=input_shape)

# Create U-Net-like structure with EfficientNetB0 as encoder
inputs = Input(shape=input_shape)
x = base_model(inputs, training=True)
x = UpSampling2D()(x)
x = Conv2D(256, (3, 3), activation='relu', padding='same')(x)
x = UpSampling2D()(x)
x = Conv2D(128, (3, 3), activation='relu', padding='same')(x)
x = UpSampling2D()(x)
x = Conv2D(64, (3, 3), activation='relu', padding='same')(x)
x = UpSampling2D()(x)
x = Conv2D(32, (3, 3), activation='relu', padding='same')(x)
x = UpSampling2D()(x)
outputs = Conv2D(1, (1, 1), activation='sigmoid')(x)

model = Model(inputs, outputs)
# Out:
# Downloading data from https://storage.googleapis.com/keras-applications/efficientnetb0_notop.h5
# 16705208/16705208 [==============================] - 0s 0us/step

# %%
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.losses import binary_crossentropy

model.compile(optimizer=Adam(learning_rate=0.0001), loss=binary_crossentropy, metrics=['accuracy'])

# %%
from tensorflow.keras.callbacks import ModelCheckpoint, ReduceLROnPlateau, EarlyStopping

checkpoint = ModelCheckpoint("best_model.h5", save_best_only=True, verbose=1)
reduce_lr = ReduceLROnPlateau(factor=0.1, patience=5, min_lr=0.000001, verbose=1)
early_stop = EarlyStopping(patience=10, restore_best_weights=True, verbose=1)

history = model.fit(
    train_generator,
    steps_per_epoch=898 // 32,
    validation_data=val_generator,
    validation_steps=379 // 32,
    epochs=50,
    callbacks=[checkpoint, reduce_lr, early_stop]
)
# Out:
# Epoch 1/50
# 28/28 [==============================] - ETA: 0s - loss: 0.4355 - accuracy: 0.8009
# Epoch 1: val_loss improved from inf to 0.30015, saving model to best_model.h5
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3000: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 28/28 [==============================] - 510s 17s/step - loss: 0.4355 - accuracy: 0.8009 - val_loss: 0.3002 - val_accuracy: 0.8782 - lr: 1.0000e-04
# Epoch 2/50
# 28/28 [==============================] - ETA: 0s - loss: 0.2433 - accuracy: 0.8980
# Epoch 2: val_loss improved from 0.30015 to 0.25075, saving model to best_model.h5
# 28/28 [==============================] - 46s 2s/step - loss: 0.2433 - accuracy: 0.8980 - val_loss: 0.2507 - val_accuracy: 0.8940 - lr: 1.0000e-04
# Epoch 3/50
# 28/28 [==============================] - ETA: 0s - loss: 0.1979 - accuracy: 0.9158
# Epoch 3: val_loss improved from 0.25075 to 0.24545, saving model to best_model.h5
# 28/28 [==============================] - 43s 2s/step - loss: 0.1979 - accuracy: 0.9158 - val_loss: 0.2455 - val_accuracy: 0.8988 - lr: 1.0000e-04
# Epoch 4/50
# 28/28 [==============================] - ETA: 0s - loss: 0.1712 - accuracy: 0.9272
# Epoch 4: val_loss improved from 0.24545 to 0.23527, saving model to best_model.h5
# 28/28 [==============================] - 40s 1s/step - loss: 0.1712 - accuracy: 0.9272 - val_loss: 0.2353 - val_accuracy: 0.9041 - lr: 1.0000e-04
# Epoch 5/50
# 28/28 [==============================] - ETA: 0s - loss: 0.1534 - accuracy: 0.9343
# Epoch 5: val_loss improved from 0.23527 to 0.21484, saving model to best_model.h5
# 28/28 [==============================] - 35s 1s/step - loss: 0.1534 - accuracy: 0.9343 - val_loss: 0.2148 - val_accuracy: 0.9108 - lr: 1.0000e-04
# Epoch 6/50
# 28/28 [==============================] - ETA: 0s - loss: 0.1534 - accuracy: 0.9355
# Epoch 6: val_loss did not improve from 0.21484
# 28/28 [==============================] - 31s 1s/step - loss: 0.1534 - accuracy: 0.9355 - val_loss: 0.2221 - val_accuracy: 0.9114 - lr: 1.0000e-04
# Epoch 7/50
# 28/28 [==============================] - ETA: 0s - loss: 0.1328 - accuracy: 0.9437
# Epoch 7: val_loss improved from 0.21484 to 0.20768, saving model to best_model.h5
# 28/28 [==============================] - 34s 1s/step - loss: 0.1328 - accuracy: 0.9437 - val_loss: 0.2077 - val_accuracy: 0.9141 - lr: 1.0000e-04
# Epoch 8/50
# 28/28 [==============================] - ETA: 0s - loss: 0.1269 - accuracy: 0.9461
# Epoch 8: val_loss did not improve from 0.20768
# 28/28 [==============================] - 30s 1s/step - loss: 0.1269 - accuracy: 0.9461 - val_loss: 0.2085 - val_accuracy: 0.9161 - lr: 1.0000e-04
# Epoch 9/50
# 28/28 [==============================] - ETA: 0s - loss: 0.1248 - accuracy: 0.9464
# Epoch 9: val_loss did not improve from 0.20768
# 28/28 [==============================] - 31s 1s/step - loss: 0.1248 - accuracy: 0.9464 - val_loss: 0.2130 - val_accuracy: 0.9134 - lr: 1.0000e-04
# Epoch 10/50
# 28/28 [==============================] - ETA: 0s - loss: 0.1177 - accuracy: 0.9495
# Epoch 10: val_loss did not improve from 0.20768
# 28/28 [==============================] - 32s 1s/step - loss: 0.1177 - accuracy: 0.9495 - val_loss: 0.2078 - val_accuracy: 0.9190 - lr: 1.0000e-04
# Epoch 11/50
# 28/28 [==============================] - ETA: 0s - loss: 0.1100 - accuracy: 0.9526
# Epoch 11: val_loss did not improve from 0.20768
# 28/28 [==============================] - 37s 1s/step - loss: 0.1100 - accuracy: 0.9526 - val_loss: 0.2082 - val_accuracy: 0.9187 - lr: 1.0000e-04
# Epoch 12/50
# 28/28 [==============================] - ETA: 0s - loss: 0.1001 - accuracy: 0.9570
# Epoch 12: val_loss improved from 0.20768 to 0.19792, saving model to best_model.h5
# 28/28 [==============================] - 30s 1s/step - loss: 0.1001 - accuracy: 0.9570 - val_loss: 0.1979 - val_accuracy: 0.9232 - lr: 1.0000e-04
# Epoch 13/50
# 28/28 [==============================] - ETA: 0s - loss: 0.1012 - accuracy: 0.9566
# Epoch 13: val_loss improved from 0.19792 to 0.19431, saving model to best_model.h5
# 28/28 [==============================] - 32s 1s/step - loss: 0.1012 - accuracy: 0.9566 - val_loss: 0.1943 - val_accuracy: 0.9238 - lr: 1.0000e-04
# Epoch 14/50
# 28/28 [==============================] - ETA: 0s - loss: 0.0991 - accuracy: 0.9576
# Epoch 14: val_loss did not improve from 0.19431
# 28/28 [==============================] - 34s 1s/step - loss: 0.0991 - accuracy: 0.9576 - val_loss: 0.2026 - val_accuracy: 0.9229 - lr: 1.0000e-04
# Epoch 15/50
# 28/28 [==============================] - ETA: 0s - loss: 0.0964 - accuracy: 0.9585
# Epoch 15: val_loss did not improve from 0.19431
# 28/28 [==============================] - 35s 1s/step - loss: 0.0964 - accuracy: 0.9585 - val_loss: 0.2004 - val_accuracy: 0.9227 - lr: 1.0000e-04
# Epoch 16/50
# 28/28 [==============================] - ETA: 0s - loss: 0.0911 - accuracy: 0.9608
# Epoch 16: val_loss did not improve from 0.19431
# 28/28 [==============================] - 32s 1s/step - loss: 0.0911 - accuracy: 0.9608 - val_loss: 0.1963 - val_accuracy: 0.9257 - lr: 1.0000e-04
# Epoch 17/50
# 28/28 [==============================] - ETA: 0s - loss: 0.0900 - accuracy: 0.9613
# Epoch 17: val_loss did not improve from 0.19431
# 28/28 [==============================] - 38s 1s/step - loss: 0.0900 - accuracy: 0.9613 - val_loss: 0.1944 - val_accuracy: 0.9266 - lr: 1.0000e-04
# Epoch 18/50
# 28/28 [==============================] - ETA: 0s - loss: 0.0863 - accuracy: 0.9630
# Epoch 18: val_loss improved from 0.19431 to 0.18256, saving model to best_model.h5
# 28/28 [==============================] - 28s 1s/step - loss: 0.0863 - accuracy: 0.9630 - val_loss: 0.1826 - val_accuracy: 0.9285 - lr: 1.0000e-04
# Epoch 19/50
# 28/28 [==============================] - ETA: 0s - loss: 0.0835 - accuracy: 0.9639
# Epoch 19: val_loss did not improve from 0.18256
# 28/28 [==============================] - 35s 1s/step - loss: 0.0835 - accuracy: 0.9639 - val_loss: 0.1903 - val_accuracy: 0.9293 - lr: 1.0000e-04
# Epoch 20/50
# 28/28 [==============================] - ETA: 0s - loss: 0.0849 - accuracy: 0.9634
# Epoch 20: val_loss did not improve from 0.18256
# 28/28 [==============================] - 29s 1s/step - loss: 0.0849 - accuracy: 0.9634 - val_loss: 0.1968 - val_accuracy: 0.9278 - lr: 1.0000e-04
# Epoch 21/50
# 28/28 [==============================] - ETA: 0s - loss: 0.0973 - accuracy: 0.9588
# Epoch 21: val_loss did not improve from 0.18256
# 28/28 [==============================] - 32s 1s/step - loss: 0.0973 - accuracy: 0.9588 - val_loss: 0.1894 - val_accuracy: 0.9220 - lr: 1.0000e-04
# Epoch 22/50
# 28/28 [==============================] - ETA: 0s - loss: 0.0987 - accuracy: 0.9592
# Epoch 22: val_loss did not improve from 0.18256
# 28/28 [==============================] - 36s 1s/step - loss: 0.0987 - accuracy: 0.9592 - val_loss: 0.1980 - val_accuracy: 0.9278 - lr: 1.0000e-04
# Epoch 23/50
# 28/28 [==============================] - ETA: 0s - loss: 0.0806 - accuracy: 0.9656
# Epoch 23: val_loss did not improve from 0.18256
#
# Epoch 23: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-06.
# 28/28 [==============================] - 32s 1s/step - loss: 0.0806 - accuracy: 0.9656 - val_loss: 0.1835 - val_accuracy: 0.9299 - lr: 1.0000e-04
# Epoch 24/50
# 28/28 [==============================] - ETA: 0s - loss: 0.0778 - accuracy: 0.9668
# Epoch 24: val_loss did not improve from 0.18256
# 28/28 [==============================] - 36s 1s/step - loss: 0.0778 - accuracy: 0.9668 - val_loss: 0.1851 - val_accuracy: 0.9300 - lr: 1.0000e-05
# Epoch 25/50
# 28/28 [==============================] - ETA: 0s - loss: 0.0766 - accuracy: 0.9674
# Epoch 25: val_loss did not improve from 0.18256
# 28/28 [==============================] - 33s 1s/step - loss: 0.0766 - accuracy: 0.9674 - val_loss: 0.1865 - val_accuracy: 0.9304 - lr: 1.0000e-05
# Epoch 26/50
# 28/28 [==============================] - ETA: 0s - loss: 0.0751 - accuracy: 0.9682
# Epoch 26: val_loss did not improve from 0.18256
# 28/28 [==============================] - 32s 1s/step - loss: 0.0751 - accuracy: 0.9682 - val_loss: 0.1856 - val_accuracy: 0.9304 - lr: 1.0000e-05
# Epoch 27/50
# 28/28 [==============================] - ETA: 0s - loss: 0.0757 - accuracy: 0.9679
# Epoch 27: val_loss did not improve from 0.18256
# 28/28 [==============================] - 33s 1s/step - loss: 0.0757 - accuracy: 0.9679 - val_loss: 0.1827 - val_accuracy: 0.9314 - lr: 1.0000e-05
# Epoch 28/50
# 28/28 [==============================] - ETA: 0s - loss: 0.0775 - accuracy: 0.9670
# Epoch 28: val_loss did not improve from 0.18256
#
# Epoch 28: ReduceLROnPlateau reducing learning rate to 1e-06.
# Restoring model weights from the end of the best epoch: 18.
# 28/28 [==============================] - 29s 1s/step - loss: 0.0775 - accuracy: 0.9670 - val_loss: 0.1846 - val_accuracy: 0.9306 - lr: 1.0000e-05
# Epoch 28: early stopping

# %%
# 6. Save the model
model.save("skin_cancer_efficientnet_model.h5")

# %%
import os
import numpy as np
from tensorflow.keras.models import load_model
from tensorflow.keras.preprocessing.image import load_img, img_to_array
from PIL import Image

# Load the trained EfficientNet model
efficientnet_model = load_model('efficientnet_best_model.h5')

# Test dataset directory
test_images_dir = '/content/drive/MyDrive/EfficientNet/ISBI2016_ISIC_Part1_Test_Data/'

# %%
# Define image dimensions for EfficientNet
IMG_WIDTH = 128
IMG_HEIGHT = 128
IMG_CHANNELS = 3

# Load and preprocess the test images
test_image_files = os.listdir(test_images_dir)
X_test = np.zeros((len(test_image_files), IMG_HEIGHT, IMG_WIDTH, IMG_CHANNELS), dtype=np.uint8)
for n, image_file in enumerate(test_image_files):
    image_path = os.path.join(test_images_dir, image_file)
    img = load_img(image_path, target_size=(IMG_HEIGHT, IMG_WIDTH))
    X_test[n] = img_to_array(img)

# %%
# Predict using the EfficientNet model
efficientnet_predictions = efficientnet_model.predict(X_test)
# Out:
# 12/12 [==============================] - 3s 37ms/step

# %%
# Save the predictions as images
save_dir = '/content/drive/MyDrive/EfficientNet/predicted_masks_efficientnet/'
if not os.path.exists(save_dir):
    os.makedirs(save_dir)

# %%
for i, pred_mask in enumerate(efficientnet_predictions):
    # Squeeze out the last dimension to get a 2D array
    mask_2d = np.squeeze(pred_mask, axis=-1)

    # Convert the mask values to the range [0, 255] and then to uint8 type
    mask_to_save = (mask_2d * 255).astype(np.uint8)

    # Convert the numpy array to a PIL image
    mask_img = Image.fromarray(mask_to_save)

    # Extract the base name of the original test image
    base_name = os.path.splitext(test_image_files[i])[0]

    # Create the filename for the predicted mask
    mask_filename = os.path.join(save_dir, base_name + "_Segmentation.png")

    # Save the PIL image
    mask_img.save(mask_filename)

# %%
import os
import numpy as np
from skimage.io import imread
from skimage.transform import resize

# Paths for the predicted masks and ground truth masks
predicted_masks_path = '/content/drive/MyDrive/EfficientNet/predicted_masks_efficientnet/'
ground_truth_path = '/content/drive/MyDrive/EfficientNet/ISBI2016_ISIC_Part1_Test_GroundTruth/'

def compute_iou(mask1, mask2):
    """Compute Intersection over Union (IoU) of two binary masks."""
    intersection = np.logical_and(mask1, mask2)
    union = np.logical_or(mask1, mask2)
    return np.sum(intersection) / np.sum(union)

def compute_dice(mask1, mask2):
    """Compute Dice Coefficient of two binary masks."""
    intersection = np.logical_and(mask1, mask2)
    return 2. * np.sum(intersection) / (np.sum(mask1) + np.sum(mask2))

ious = []
dices = []

for mask_file in os.listdir(predicted_masks_path):
    predicted_mask = imread(os.path.join(predicted_masks_path, mask_file))
    ground_truth_mask_original = imread(os.path.join(ground_truth_path, mask_file))

    # Resize the ground truth mask to 128x128
    ground_truth_mask = resize(ground_truth_mask_original, (128, 128), mode='constant', preserve_range=True)

    # Binarize the masks for metric computation
    predicted_mask_binarized = (predicted_mask > 127).astype(np.uint8)
    ground_truth_mask_binarized = (ground_truth_mask > 127).astype(np.uint8)

    iou = compute_iou(predicted_mask_binarized, ground_truth_mask_binarized)
    dice = compute_dice(predicted_mask_binarized, ground_truth_mask_binarized)

    ious.append(iou)
    dices.append(dice)

# Compute average IoU and Dice Coefficient
avg_iou = np.mean(ious)
avg_dice = np.mean(dices)

print(f"Average IoU: {avg_iou:.4f}")
print(f"Average Dice Coefficient: {avg_dice:.4f}")
# Out:
# Average IoU: 0.6001
# Average Dice Coefficient: 0.7214

# %%
import os
import numpy as np
from skimage.io import imread

# Directory paths
predicted_masks_path = '/content/drive/MyDrive/EfficientNet/predicted_masks_efficientnet/'

# Get list of predicted mask files
mask_files = os.listdir(predicted_masks_path)

# Lists to store results
coverage_percentages = []
risk_categories = []
interpretations = []

# Iterate through each predicted mask
for mask_file in mask_files:
    mask_path = os.path.join(predicted_masks_path, mask_file)
    mask = imread(mask_path)

    # Binarize the mask
    mask_binarized = (mask > 127).astype(np.uint8)

    # Compute coverage percentage
    coverage = (np.sum(mask_binarized) / (mask_binarized.shape[0] * mask_binarized.shape[1])) * 100
    coverage_percentages.append(coverage)

    # Determine risk category and interpretation
    if coverage < 5:
        risk_categories.append("Low Risk")
        interpretations.append("The analysis indicates a low presence of abnormal tissue. While it appears likely benign, always consider a professional dermatologist's advice.")
    elif coverage >= 5 and coverage <= 15:
        risk_categories.append("Medium Risk")
        interpretations.append("The model has identified some regions of potential concern. It's recommended to consult a dermatologist for a more detailed examination.")
    else:
        risk_categories.append("High Risk")
        interpretations.append("The analysis indicates a significant presence of abnormal tissue. Immediate consultation with a dermatologist is advised.")

# You can now use the lists `coverage_percentages`, `risk_categories`, and `interpretations` for further analysis or display.

# %%
# Assuming you've run the previous code and have the lists `coverage_percentages`, `risk_categories`, and `interpretations`

for i, mask_file in enumerate(mask_files):
    print(f"Image: {mask_file}")
    print(f"Coverage Percentage: {coverage_percentages[i]:.2f}%")
    print(f"Risk Category: {risk_categories[i]}")
    print(f"Interpretation: {interpretations[i]}")
    print("-" * 50)  # to separate the results for each image
# Out:
# Image: ISIC_0000040_Segmentation.png
# Coverage Percentage: 10.52%
# Risk Category: Medium Risk
# Interpretation: The model has identified some regions of potential concern. It's recommended to consult a dermatologist for a more detailed examination.
# --------------------------------------------------
# Image: ISIC_0000015_Segmentation.png
# Coverage Percentage: 21.14%
# Risk Category: High Risk
# Interpretation: The analysis indicates a significant presence of abnormal tissue. Immediate consultation with a dermatologist is advised.
# --------------------------------------------------
# Image: ISIC_0000012_Segmentation.png
# Coverage Percentage: 3.17%
# Risk Category: Low Risk
# Interpretation: The analysis indicates a low presence of abnormal tissue. While it appears likely benign, always consider a professional dermatologist's advice.
# --------------------------------------------------
# Image: ISIC_0000023_Segmentation.png
# Coverage Percentage: 17.60%
# Risk Category: High Risk
# Interpretation: The analysis indicates a significant presence of abnormal tissue. Immediate consultation with a dermatologist is advised.
# --------------------------------------------------
# Image: ISIC_0000020_Segmentation.png
# Coverage Percentage: 22.12%
# Risk Category: High Risk
# Interpretation: The analysis indicates a significant presence of abnormal tissue. Immediate consultation with a dermatologist is advised.
# --------------------------------------------------
# Image: ISIC_0000036_Segmentation.png
# Coverage Percentage: 31.91%
# Risk Category: High Risk
# Interpretation: The analysis indicates a significant presence of abnormal tissue. Immediate consultation with a dermatologist is advised.
# --------------------------------------------------
# Image: ISIC_0000052_Segmentation.png
# Coverage Percentage: 59.20%
# Risk Category: High Risk
# Interpretation: The analysis indicates a significant presence of abnormal tissue. Immediate consultation with a dermatologist is advised.
# --------------------------------------------------
# Image: ISIC_0000053_Segmentation.png
# Coverage Percentage: 40.41%
# Risk Category: High Risk
# Interpretation: The analysis indicates a significant presence of abnormal tissue. Immediate consultation with a dermatologist is advised.
# --------------------------------------------------
# Image: ISIC_0000014_Segmentation.png
# Coverage Percentage: 37.18%
# Risk Category: High Risk
# Interpretation: The analysis indicates a significant presence of abnormal tissue. Immediate consultation with a dermatologist is advised.
# --------------------------------------------------
# Image: ISIC_0000003_Segmentation.png
# Coverage Percentage: 38.62%
# Risk Category: High Risk
# Interpretation: The analysis indicates a significant presence of abnormal tissue. Immediate consultation with a dermatologist is advised.
# --------------------------------------------------
# Image: ISIC_0000013_Segmentation.png
# Coverage Percentage: 22.78%
# Risk Category: High Risk
# Interpretation: The analysis indicates a significant presence of abnormal tissue. Immediate consultation with a dermatologist is advised.
# --------------------------------------------------
# Image: ISIC_0000022_Segmentation.png
# Coverage Percentage: 27.88%
# Risk Category: High Risk
# Interpretation: The analysis indicates a significant presence of abnormal tissue. Immediate consultation with a dermatologist is advised.
# --------------------------------------------------
# Image: ISIC_0000037_Segmentation.png
# Coverage Percentage: 37.01%
# Risk Category: High Risk
# Interpretation: The analysis indicates a significant presence of abnormal tissue. Immediate consultation with a dermatologist is advised.
# --------------------------------------------------
# Image: ISIC_0000043_Segmentation.png
# Coverage Percentage: 56.01%
# Risk Category: High Risk
# Interpretation: The analysis indicates a significant presence of abnormal tissue. Immediate consultation with a dermatologist is advised.
# --------------------------------------------------
# Image: ISIC_0000027_Segmentation.png
# Coverage Percentage: 10.91%
# Risk Category: Medium Risk
# Interpretation: The model has identified some regions of potential concern. It's recommended to consult a dermatologist for a more detailed examination.
# --------------------------------------------------
# Image: ISIC_0000115_Segmentation.png
# Coverage Percentage: 0.00%
# Risk Category: Low Risk
# Interpretation: The analysis indicates a low presence of abnormal tissue. While it appears likely benign, always consider a professional dermatologist's advice.
# --------------------------------------------------
# Image: ISIC_0000172_Segmentation.png
# Coverage Percentage: 33.94%
# Risk Category: High Risk
# Interpretation: The analysis indicates a significant presence of abnormal tissue. Immediate consultation with a dermatologist is advised.
# --------------------------------------------------
# Image: ISIC_0000117_Segmentation.png
# Coverage Percentage: 20.46%
# Risk Category: High Risk
# Interpretation: The analysis indicates a significant presence of abnormal tissue. Immediate consultation with a dermatologist is advised.
# --------------------------------------------------
# Image: ISIC_0000057_Segmentation.png
# Coverage Percentage: 18.29%
# Risk Category: High Risk
# Interpretation: The analysis indicates a significant presence of abnormal tissue. Immediate consultation with a dermatologist is advised.
# --------------------------------------------------
# Image: ISIC_0000188_Segmentation.png
# Coverage Percentage: 35.91%
# Risk Category: High Risk
# Interpretation: The analysis indicates a significant presence of abnormal tissue. Immediate consultation with a dermatologist is advised.
# --------------------------------------------------
# Image: ISIC_0000129_Segmentation.png
# Coverage Percentage: 15.77%
# Risk Category: High Risk
# Interpretation: The analysis indicates a significant presence of abnormal tissue. Immediate consultation with a dermatologist is advised.
# --------------------------------------------------
# Image: ISIC_0000161_Segmentation.png
# Coverage Percentage: 36.52%
# Risk Category: High Risk
# Interpretation: The analysis indicates a significant presence of abnormal tissue. Immediate consultation with a dermatologist is advised.
# --------------------------------------------------
# Image: ISIC_0000107_Segmentation.png
# Coverage Percentage: 13.04%
# Risk Category: Medium Risk
# Interpretation: The model has identified some regions of potential concern. It's recommended to consult a dermatologist for a more detailed examination.
# --------------------------------------------------
# Image: ISIC_0000160_Segmentation.png
# Coverage Percentage: 70.78%
# Risk Category: High Risk
# Interpretation: The analysis indicates a significant presence of abnormal tissue. Immediate consultation with a dermatologist is advised.
# --------------------------------------------------
# Image: ISIC_0000111_Segmentation.png
# Coverage Percentage: 43.19%
# Risk Category: High Risk
# Interpretation: The analysis indicates a significant presence of abnormal tissue. Immediate consultation with a dermatologist is advised.
# --------------------------------------------------
# Image: ISIC_0000069_Segmentation.png
# Coverage Percentage: 19.68%
# Risk Category: High Risk
# Interpretation: The analysis indicates a significant presence of abnormal tissue. Immediate consultation with a dermatologist is advised.
# --------------------------------------------------
# Image: ISIC_0000056_Segmentation.png
# Coverage Percentage: 30.96%
# Risk Category: High Risk
# Interpretation: The analysis indicates a significant presence of abnormal tissue. Immediate consultation with a dermatologist is advised.
# --------------------------------------------------
# Image: ISIC_0000072_Segmentation.png
# Coverage Percentage: 15.26%
# Risk Category: High Risk
# Interpretation: The analysis indicates a significant presence of abnormal tissue. Immediate consultation with a dermatologist is advised.
# --------------------------------------------------
# Image: ISIC_0000164_Segmentation.png
# Coverage Percentage: 31.96%
# Risk Category: High Risk
# Interpretation: The analysis indicates a significant presence of abnormal tissue. Immediate consultation with a dermatologist is advised.
# --------------------------------------------------
# Image: ISIC_0000088_Segmentation.png
# Coverage Percentage: 19.56%
# Risk Category: High Risk
# Interpretation: The analysis indicates a significant presence of abnormal tissue. Immediate consultation with a dermatologist is advised.
# --------------------------------------------------
# Image: ISIC_0000101_Segmentation.png
# Coverage Percentage: 32.67%
# Risk Category: High Risk
# Interpretation: The analysis indicates a significant presence of abnormal tissue. Immediate consultation with a dermatologist is advised.
# --------------------------------------------------
# Image: ISIC_0000195_Segmentation.png
# Coverage Percentage: 52.17%
# Risk Category: High Risk
# Interpretation: The analysis indicates a significant presence of abnormal tissue. Immediate consultation with a dermatologist is advised.
# --------------------------------------------------
# Image: ISIC_0000098_Segmentation.png
# Coverage Percentage: 0.00%
# Risk Category: Low Risk
# Interpretation: The analysis indicates a low presence of abnormal tissue. While it appears likely benign, always consider a professional dermatologist's advice.
# --------------------------------------------------
# Image: ISIC_0000136_Segmentation.png
# Coverage Percentage: 44.46%
# Risk Category: High Risk
# Interpretation: The analysis indicates a significant presence of abnormal tissue. Immediate consultation with a dermatologist is advised.
# --------------------------------------------------
# Image: ISIC_0000177_Segmentation.png
# Coverage Percentage: 6.27%
# Risk Category: Medium Risk
# Interpretation: The model has identified some regions of potential concern. It's recommended to consult a dermatologist for a more detailed examination.
# --------------------------------------------------
# Image: ISIC_0000099_Segmentation.png
# Coverage Percentage: 22.46%
# Risk Category: High Risk
# Interpretation: The analysis indicates a significant presence of abnormal tissue. Immediate consultation with a dermatologist is advised.
# --------------------------------------------------
# Image: ISIC_0000138_Segmentation.png
# Coverage Percentage: 19.07%
# Risk Category: High Risk
# Interpretation: The analysis indicates a significant presence of abnormal tissue. Immediate consultation with a dermatologist is advised.
# --------------------------------------------------
# Image: ISIC_0000165_Segmentation.png
# Coverage Percentage: 11.30%
# Risk Category: Medium Risk
# Interpretation: The model has identified some regions of potential concern. It's recommended to consult a dermatologist for a more detailed examination.
# --------------------------------------------------
# Image: ISIC_0000169_Segmentation.png
# Coverage Percentage: 27.32%
# Risk Category: High Risk
# Interpretation: The analysis indicates a significant presence of abnormal tissue. Immediate consultation with a dermatologist is advised.
# --------------------------------------------------
# Image: ISIC_0000174_Segmentation.png
# Coverage Percentage: 23.97%
# Risk Category: High Risk
# Interpretation: The analysis indicates a significant presence of abnormal tissue. Immediate consultation with a dermatologist is advised.
# --------------------------------------------------
# Image: ISIC_0000141_Segmentation.png
# Coverage Percentage: 17.48%
# Risk Category: High Risk
# Interpretation: The analysis indicates a significant presence of abnormal tissue. Immediate consultation with a dermatologist is advised.
# --------------------------------------------------
# Image: ISIC_0000113_Segmentation.png
# Coverage Percentage: 17.09%
# Risk Category: High Risk
# Interpretation: The analysis indicates a significant presence of abnormal tissue. Immediate consultation with a dermatologist is advised.
# --------------------------------------------------
# Image: ISIC_0000149_Segmentation.png
# Coverage Percentage: 43.14%
# Risk Category: High Risk
# Interpretation: The analysis indicates a significant presence of abnormal tissue. Immediate consultation with a dermatologist is advised.
# --------------------------------------------------
# Image: ISIC_0000066_Segmentation.png
# Coverage Percentage: 36.38%
# Risk Category: High Risk
# Interpretation: The analysis indicates a significant presence of abnormal tissue. Immediate consultation with a dermatologist is advised.
# --------------------------------------------------
# Image: ISIC_0000071_Segmentation.png
# Coverage Percentage: 10.99%
# Risk Category: Medium Risk
# Interpretation: The model has identified some regions of potential concern. It's recommended to consult a dermatologist for a more detailed examination.
# --------------------------------------------------
# Image: ISIC_0000126_Segmentation.png
# Coverage Percentage: 28.93%
# Risk Category: High Risk
# Interpretation: The analysis indicates a significant presence of abnormal tissue. Immediate consultation with a dermatologist is advised.
# --------------------------------------------------
# Image: ISIC_0000125_Segmentation.png
# Coverage Percentage: 7.37%
# Risk Category: Medium Risk
# Interpretation: The model has identified some regions of potential concern. It's recommended to consult a dermatologist for a more detailed examination.
# --------------------------------------------------
# Image: ISIC_0000092_Segmentation.png
# Coverage Percentage: 2.93%
# Risk Category: Low Risk
# Interpretation: The analysis indicates a low presence of abnormal tissue. While it appears likely benign, always consider a professional dermatologist's advice.
# --------------------------------------------------
# Image: ISIC_0000132_Segmentation.png
# Coverage Percentage: 5.96%
# Risk Category: Medium Risk
# Interpretation: The model has identified some regions of potential concern. It's recommended to consult a dermatologist for a more detailed examination.
# --------------------------------------------------
# Image: ISIC_0000064_Segmentation.png
# Coverage Percentage: 37.94%
# Risk Category: High Risk
# Interpretation: The analysis indicates a significant presence of abnormal tissue. Immediate consultation with a dermatologist is advised.
# --------------------------------------------------
# Image: ISIC_0000227_Segmentation.png
# Coverage Percentage: 4.03%
# Risk Category: Low Risk
# Interpretation: The analysis indicates a low presence of abnormal tissue. While it appears likely benign, always consider a professional dermatologist's advice.
# --------------------------------------------------
# Image: ISIC_0000271_Segmentation.png
# Coverage Percentage: 20.92%
# Risk Category: High Risk
# Interpretation: The analysis indicates a significant presence of abnormal tissue. Immediate consultation with a dermatologist is advised.
# --------------------------------------------------
# Image: ISIC_0000302_Segmentation.png
# Coverage Percentage: 47.68%
# Risk Category: High Risk
# Interpretation: The analysis indicates a significant presence of abnormal tissue. Immediate consultation with a dermatologist is advised.
# --------------------------------------------------
# Image: ISIC_0000196_Segmentation.png
# Coverage Percentage: 31.84%
# Risk Category: High Risk
# Interpretation: The analysis indicates a significant presence of abnormal tissue. Immediate consultation with a dermatologist is advised.
# --------------------------------------------------
# Image: ISIC_0000201_Segmentation.png
# Coverage Percentage: 18.87%
# Risk Category: High Risk
# Interpretation: The analysis indicates a significant presence of abnormal tissue. Immediate consultation with a dermatologist is advised.
# --------------------------------------------------
# Image: ISIC_0000197_Segmentation.png
# Coverage Percentage: 25.61%
# Risk Category: High Risk
# Interpretation: The analysis indicates a significant presence of abnormal tissue. Immediate consultation with a dermatologist is advised.
# --------------------------------------------------
# Image: ISIC_0000299_Segmentation.png
# Coverage Percentage: 41.21%
# Risk Category: High Risk
# Interpretation: The analysis indicates a significant presence of abnormal tissue. Immediate consultation with a dermatologist is advised.
# --------------------------------------------------
# Image: ISIC_0000343_Segmentation.png
# Coverage Percentage: 64.53%
# Risk Category: High Risk
# Interpretation: The analysis indicates a significant presence of abnormal tissue. Immediate consultation with a dermatologist is advised.
# --------------------------------------------------
# Image: ISIC_0000226_Segmentation.png
# Coverage Percentage: 37.43%
# Risk Category: High Risk
# Interpretation: The analysis indicates a significant presence of abnormal tissue. Immediate consultation with a dermatologist is advised.
# --------------------------------------------------
# Image: ISIC_0000340_Segmentation.png
# Coverage Percentage: 12.62%
# Risk Category: Medium Risk
# Interpretation: The model has identified some regions of potential concern. It's recommended to consult a dermatologist for a more detailed examination.
# --------------------------------------------------
# Image: ISIC_0000230_Segmentation.png
# Coverage Percentage: 55.98%
# Risk Category: High Risk
# Interpretation: The analysis indicates a significant presence of abnormal tissue. Immediate consultation with a dermatologist is advised.
# --------------------------------------------------
# Image: ISIC_0000279_Segmentation.png
# Coverage Percentage: 54.47%
# Risk Category: High Risk
# Interpretation: The analysis indicates a significant presence of abnormal tissue. Immediate consultation with a dermatologist is advised.
# --------------------------------------------------
# Image: ISIC_0000228_Segmentation.png
# Coverage Percentage: 36.28%
# Risk Category: High Risk
# Interpretation: The analysis indicates a significant presence of abnormal tissue. Immediate consultation with a dermatologist is advised.
# --------------------------------------------------
# Image: ISIC_0000202_Segmentation.png
# Coverage Percentage: 69.92%
# Risk Category: High Risk
# Interpretation: The analysis indicates a significant presence of abnormal tissue. Immediate consultation with a dermatologist is advised.
# --------------------------------------------------
# Image: ISIC_0000246_Segmentation.png
# Coverage Percentage: 44.41%
# Risk Category: High Risk
# Interpretation: The analysis indicates a significant presence of abnormal tissue. Immediate consultation with a dermatologist is advised.
# --------------------------------------------------
# Image: ISIC_0000258_Segmentation.png
# Coverage Percentage: 35.72%
# Risk Category: High Risk
# Interpretation: The analysis indicates a significant presence of abnormal tissue. Immediate consultation with a dermatologist is advised.
# --------------------------------------------------
# Image: ISIC_0000287_Segmentation.png
# Coverage Percentage: 32.03%
# Risk Category: High Risk
# Interpretation: The analysis indicates a significant presence of abnormal tissue. Immediate consultation with a dermatologist is advised.
# --------------------------------------------------
# Image: ISIC_0000310_Segmentation.png
# Coverage Percentage: 77.54%
# Risk Category: High Risk
# Interpretation: The analysis indicates a significant presence of abnormal tissue. Immediate consultation with a dermatologist is advised.
# --------------------------------------------------
# Image: ISIC_0000212_Segmentation.png
# Coverage Percentage: 60.25%
# Risk Category: High Risk
# Interpretation: The analysis indicates a significant presence of abnormal tissue. Immediate consultation with a dermatologist is advised.
# --------------------------------------------------
# Image: ISIC_0000200_Segmentation.png
# Coverage Percentage: 15.94%
# Risk Category: High Risk
# Interpretation: The analysis indicates a significant presence of abnormal tissue. Immediate consultation with a dermatologist is advised.
# --------------------------------------------------
# Image: ISIC_0000253_Segmentation.png
# Coverage Percentage: 9.33%
# Risk Category: Medium Risk
# Interpretation: The model has identified some regions of potential concern. It's recommended to consult a dermatologist for a more detailed examination.
# --------------------------------------------------
# Image: ISIC_0000213_Segmentation.png
# Coverage Percentage: 36.38%
# Risk Category: High Risk
# Interpretation: The analysis indicates a significant presence of abnormal tissue. Immediate consultation with a dermatologist is advised.
# --------------------------------------------------
# Image: ISIC_0000289_Segmentation.png
# Coverage Percentage: 65.11%
# Risk Category: High Risk
# Interpretation: The analysis indicates a significant presence of abnormal tissue. Immediate consultation with a dermatologist is advised.
# --------------------------------------------------
# Image: ISIC_0000233_Segmentation.png
# Coverage Percentage: 69.87%
# Risk Category: High Risk
# Interpretation: The analysis indicates a significant presence of abnormal tissue. Immediate consultation with a dermatologist is advised.
# --------------------------------------------------
# Image: ISIC_0000328_Segmentation.png
# Coverage Percentage: 21.58%
# Risk Category: High Risk
# Interpretation: The analysis indicates a significant presence of abnormal tissue. Immediate consultation with a dermatologist is advised.
# --------------------------------------------------
# Image: ISIC_0000234_Segmentation.png
# Coverage Percentage: 39.23%
# Risk Category: High Risk
# Interpretation: The analysis indicates a significant presence of abnormal tissue. Immediate consultation with a dermatologist is advised.
# --------------------------------------------------
# Image: ISIC_0000320_Segmentation.png
# Coverage Percentage: 17.14%
# Risk Category: High Risk
# Interpretation: The analysis indicates a significant presence of abnormal tissue. Immediate consultation with a dermatologist is advised.
# --------------------------------------------------
# Image: ISIC_0000368_Segmentation.png
# Coverage Percentage: 46.17%
# Risk Category: High Risk
# Interpretation: The analysis indicates a significant presence of abnormal tissue. Immediate consultation with a dermatologist is advised.
# --------------------------------------------------
# Image: ISIC_0000198_Segmentation.png
# Coverage Percentage: 5.79%
# Risk Category: Medium Risk
# Interpretation: The model has identified some regions of potential concern. It's recommended to consult a dermatologist for a more detailed examination.
# --------------------------------------------------
# Image: ISIC_0000254_Segmentation.png
# Coverage Percentage: 20.68%
# Risk Category: High Risk
# Interpretation: The analysis indicates a significant presence of abnormal tissue. Immediate consultation with a dermatologist is advised.
# --------------------------------------------------
# Image: ISIC_0000319_Segmentation.png
# Coverage Percentage: 26.86%
# Risk Category: High Risk
# Interpretation: The analysis indicates a significant presence of abnormal tissue. Immediate consultation with a dermatologist is advised.
# --------------------------------------------------
# Image: ISIC_0000257_Segmentation.png
# Coverage Percentage: 0.00%
# Risk Category: Low Risk
# Interpretation: The analysis indicates a low presence of abnormal tissue. While it appears likely benign, always consider a professional dermatologist's advice.
# --------------------------------------------------
# Image: ISIC_0000222_Segmentation.png
# Coverage Percentage: 43.55%
# Risk Category: High Risk
# Interpretation: The analysis indicates a significant presence of abnormal tissue. Immediate consultation with a dermatologist is advised.
# --------------------------------------------------
# Image: ISIC_0000354_Segmentation.png
# Coverage Percentage: 33.96%
# Risk Category: High Risk
# Interpretation: The analysis indicates a significant presence of abnormal tissue. Immediate consultation with a dermatologist is advised.
# --------------------------------------------------
# Image: ISIC_0000298_Segmentation.png
# Coverage Percentage: 12.18%
# Risk Category: Medium Risk
# Interpretation: The model has identified some regions of potential concern. It's recommended to consult a dermatologist for a more detailed examination.
# --------------------------------------------------
# Image: ISIC_0000311_Segmentation.png
# Coverage Percentage: 80.98%
# Risk Category: High Risk
# Interpretation: The analysis indicates a significant presence of abnormal tissue. Immediate consultation with a dermatologist is advised.
# --------------------------------------------------
# Image: ISIC_0000327_Segmentation.png
# Coverage Percentage: 18.43%
# Risk Category: High Risk
# Interpretation: The analysis indicates a significant presence of abnormal tissue. Immediate consultation with a dermatologist is advised.
# --------------------------------------------------
# Image: ISIC_0000357_Segmentation.png
# Coverage Percentage: 8.74%
# Risk Category: Medium Risk
# Interpretation: The model has identified some regions of potential concern. It's recommended to consult a dermatologist for a more detailed examination.
# --------------------------------------------------
# Image: ISIC_0000306_Segmentation.png
# Coverage Percentage: 18.77%
# Risk Category: High Risk
# Interpretation: The analysis indicates a significant presence of abnormal tissue. Immediate consultation with a dermatologist is advised.
# --------------------------------------------------
# Image: ISIC_0000231_Segmentation.png
# Coverage Percentage: 28.27%
# Risk Category: High Risk
# Interpretation: The analysis indicates a significant presence of abnormal tissue. Immediate consultation with a dermatologist is advised.
# --------------------------------------------------
# Image: ISIC_0000325_Segmentation.png
# Coverage Percentage: 27.64%
# Risk Category: High Risk
# Interpretation: The analysis indicates a significant presence of abnormal tissue. Immediate consultation with a dermatologist is advised.
# --------------------------------------------------
# Image: ISIC_0000547_Segmentation.png
# Coverage Percentage: 11.65%
# Risk Category: Medium Risk
# Interpretation: The model has identified some regions of potential concern. It's recommended to consult a dermatologist for a more detailed examination.
# --------------------------------------------------
# Image: ISIC_0000525_Segmentation.png
# Coverage Percentage: 29.57%
# Risk Category: High Risk
# Interpretation: The analysis indicates a significant presence of abnormal tissue. Immediate consultation with a dermatologist is advised.
# --------------------------------------------------
# Image: ISIC_0000388_Segmentation.png
# Coverage Percentage: 8.52%
# Risk Category: Medium Risk
# Interpretation: The model has identified some regions of potential concern. It's recommended to consult a dermatologist for a more detailed examination.
# --------------------------------------------------
# Image: ISIC_0000527_Segmentation.png
# Coverage Percentage: 22.51%
# Risk Category: High Risk
# Interpretation: The analysis indicates a significant presence of abnormal tissue. Immediate consultation with a dermatologist is advised.
# --------------------------------------------------
# Image: ISIC_0000380_Segmentation.png
# Coverage Percentage: 39.99%
# Risk Category: High Risk
# Interpretation: The analysis indicates a significant presence of abnormal tissue. Immediate consultation with a dermatologist is advised.
# --------------------------------------------------
# Image: ISIC_0000456_Segmentation.png
# Coverage Percentage: 30.32%
# Risk Category: High Risk
# Interpretation: The analysis indicates a significant presence of abnormal tissue. Immediate consultation with a dermatologist is advised.
# --------------------------------------------------
# Image: ISIC_0000484_Segmentation.png
# Coverage Percentage: 38.65%
# Risk Category: High Risk
# Interpretation: The analysis indicates a significant presence of abnormal tissue. Immediate consultation with a dermatologist is advised.
# --------------------------------------------------
# Image: ISIC_0000470_Segmentation.png
# Coverage Percentage: 13.40%
# Risk Category: Medium Risk
# Interpretation: The model has identified some regions of potential concern. It's recommended to consult a dermatologist for a more detailed examination.
# --------------------------------------------------
# Image: ISIC_0000448_Segmentation.png
# Coverage Percentage: 22.46%
# Risk Category: High Risk
# Interpretation: The analysis indicates a significant presence of abnormal tissue. Immediate consultation with a dermatologist is advised.
# --------------------------------------------------
# Image: ISIC_0000537_Segmentation.png
# Coverage Percentage: 30.83%
# Risk Category: High Risk
# Interpretation: The analysis indicates a significant presence of abnormal tissue. Immediate consultation with a dermatologist is advised.
# --------------------------------------------------
# Image: ISIC_0000508_Segmentation.png
# Coverage Percentage: 29.79%
# Risk Category: High Risk
# Interpretation: The analysis indicates a significant presence of abnormal tissue. Immediate consultation with a dermatologist is advised.
# --------------------------------------------------
# Image: ISIC_0000501_Segmentation.png
# Coverage Percentage: 11.96%
# Risk Category: Medium Risk
# Interpretation: The model has identified some regions of potential concern. It's recommended to consult a dermatologist for a more detailed examination.
# --------------------------------------------------
# Image: ISIC_0000476_Segmentation.png
# Coverage Percentage: 44.14%
# Risk Category: High Risk
# Interpretation: The analysis indicates a significant presence of abnormal tissue. Immediate consultation with a dermatologist is advised.
# --------------------------------------------------
# Image: ISIC_0000549_Segmentation.png
# Coverage Percentage: 55.93%
# Risk Category: High Risk
# Interpretation: The analysis indicates a significant presence of abnormal tissue. Immediate consultation with a dermatologist is advised.
# --------------------------------------------------
# Image: ISIC_0000371_Segmentation.png
# Coverage Percentage: 34.06%
# Risk Category: High Risk
# Interpretation: The analysis indicates a significant presence of abnormal tissue. Immediate consultation with a dermatologist is advised.
# --------------------------------------------------
# Image: ISIC_0000487_Segmentation.png
# Coverage Percentage: 27.08%
# Risk Category: High Risk
# Interpretation: The analysis indicates a significant presence of abnormal tissue. Immediate consultation with a dermatologist is advised.
# --------------------------------------------------
# Image: ISIC_0000515_Segmentation.png
# Coverage Percentage: 26.68%
# Risk Category: High Risk
# Interpretation: The analysis indicates a significant presence of abnormal tissue. Immediate consultation with a dermatologist is advised.
# --------------------------------------------------
# Image: ISIC_0000490_Segmentation.png
# Coverage Percentage: 28.15%
# Risk Category: High Risk
# Interpretation: The analysis indicates a significant presence of abnormal tissue. Immediate consultation with a dermatologist is advised.
# --------------------------------------------------
# Image: ISIC_0000509_Segmentation.png
# Coverage Percentage: 16.85%
# Risk Category: High Risk
# Interpretation: The analysis indicates a significant presence of abnormal tissue. Immediate consultation with a dermatologist is advised.
# --------------------------------------------------
# Image: ISIC_0000418_Segmentation.png
# Coverage Percentage: 25.76%
# Risk Category: High Risk
# Interpretation: The analysis indicates a significant presence of abnormal tissue. Immediate consultation with a dermatologist is advised.
# --------------------------------------------------
# Image: ISIC_0000377_Segmentation.png
# Coverage Percentage: 22.66%
# Risk Category: High Risk
# Interpretation: The analysis indicates a significant presence of abnormal tissue. Immediate consultation with a dermatologist is advised.
# --------------------------------------------------
# Image: ISIC_0000479_Segmentation.png
# Coverage Percentage: 58.81%
# Risk Category: High Risk
# Interpretation: The analysis indicates a significant presence of abnormal tissue. Immediate consultation with a dermatologist is advised.
# --------------------------------------------------
# Image: ISIC_0000393_Segmentation.png
# Coverage Percentage: 44.82%
# Risk Category: High Risk
# Interpretation: The analysis indicates a significant presence of abnormal tissue. Immediate consultation with a dermatologist is advised.
# --------------------------------------------------
# Image: ISIC_0000510_Segmentation.png
# Coverage Percentage: 29.00%
# Risk Category: High Risk
# Interpretation: The analysis indicates a significant presence of abnormal tissue. Immediate consultation with a dermatologist is advised.
# --------------------------------------------------
# Image: ISIC_0000378_Segmentation.png
# Coverage Percentage: 17.63%
# Risk Category: High Risk
# Interpretation: The analysis indicates a significant presence of abnormal tissue. Immediate consultation with a dermatologist is advised.
# --------------------------------------------------
# Image: ISIC_0000482_Segmentation.png
# Coverage Percentage: 20.95%
# Risk Category: High Risk
# Interpretation: The analysis indicates a significant presence of abnormal tissue. Immediate consultation with a dermatologist is advised.
# --------------------------------------------------
# Image: ISIC_0000420_Segmentation.png
# Coverage Percentage: 15.80%
# Risk Category: High Risk
# Interpretation: The analysis indicates a significant presence of abnormal tissue. Immediate consultation with a dermatologist is advised.
# --------------------------------------------------
# Image: ISIC_0000449_Segmentation.png
# Coverage Percentage: 0.00%
# Risk Category: Low Risk
# Interpretation: The analysis indicates a low presence of abnormal tissue. While it appears likely benign, always consider a professional dermatologist's advice.
# --------------------------------------------------
# Image: ISIC_0000518_Segmentation.png
# Coverage Percentage: 20.46%
# Risk Category: High Risk
# Interpretation: The analysis indicates a significant presence of abnormal tissue. Immediate consultation with a dermatologist is advised.
# --------------------------------------------------
# Image: ISIC_0000499_Segmentation.png
# Coverage Percentage: 9.89%
# Risk Category: Medium Risk
# Interpretation: The model has identified some regions of potential concern. It's recommended to consult a dermatologist for a more detailed examination.
# --------------------------------------------------
# Image: ISIC_0000539_Segmentation.png
# Coverage Percentage: 39.09%
# Risk Category: High Risk
# Interpretation: The analysis indicates a significant presence of abnormal tissue. Immediate consultation with a dermatologist is advised.
# --------------------------------------------------
# Image: ISIC_0000433_Segmentation.png
# Coverage Percentage: 37.96%
# Risk Category: High Risk
# Interpretation: The analysis indicates a significant presence of abnormal tissue. Immediate consultation with a dermatologist is advised.
# --------------------------------------------------
# Image: ISIC_0000392_Segmentation.png
# Coverage Percentage: 18.04%
# Risk Category: High Risk
# Interpretation: The analysis indicates a significant presence of abnormal tissue. Immediate consultation with a dermatologist is advised.
# --------------------------------------------------
# Image: ISIC_0000534_Segmentation.png
# Coverage Percentage: 34.79%
# Risk Category: High Risk
# Interpretation: The analysis indicates a significant presence of abnormal tissue. Immediate consultation with a dermatologist is advised.
# --------------------------------------------------
# Image: ISIC_0000540_Segmentation.png
# Coverage Percentage: 53.56%
# Risk Category: High Risk
# Interpretation: The analysis indicates a significant presence of abnormal tissue. Immediate consultation with a dermatologist is advised.
# --------------------------------------------------
# Image: ISIC_0000466_Segmentation.png
# Coverage Percentage: 27.05%
# Risk Category: High Risk
# Interpretation: The analysis indicates a significant presence of abnormal tissue. Immediate consultation with a dermatologist is advised.
# --------------------------------------------------
# Image: ISIC_0000494_Segmentation.png
# Coverage Percentage: 10.79%
# Risk Category: Medium Risk
# Interpretation: The model has identified some regions of potential concern. It's recommended to consult a dermatologist for a more detailed examination.
# --------------------------------------------------
# Image: ISIC_0000533_Segmentation.png
# Coverage Percentage: 44.75%
# Risk Category: High Risk
# Interpretation: The analysis indicates a significant presence of abnormal tissue. Immediate consultation with a dermatologist is advised.
# --------------------------------------------------
# Image: ISIC_0000407_Segmentation.png
# Coverage Percentage: 34.84%
# Risk Category: High Risk
# Interpretation: The analysis indicates a significant presence of abnormal tissue. Immediate consultation with a dermatologist is advised.
# --------------------------------------------------
# Image: ISIC_0001204_Segmentation.png
# Coverage Percentage: 15.28%
# Risk Category: High Risk
# Interpretation: The analysis indicates a significant presence of abnormal tissue. Immediate consultation with a dermatologist is advised.
# --------------------------------------------------
# Image: ISIC_0001185_Segmentation.png
# Coverage Percentage: 5.08%
# Risk Category: Medium Risk
# Interpretation: The model has identified some regions of potential concern. It's recommended to consult a dermatologist for a more detailed examination.
# --------------------------------------------------
# Image: ISIC_0000550_Segmentation.png
# Coverage Percentage: 37.77%
# Risk Category: High Risk
# Interpretation: The analysis indicates a significant presence of abnormal tissue. Immediate consultation with a dermatologist is advised.
# --------------------------------------------------
# Image: ISIC_0001131_Segmentation.png
# Coverage Percentage: 50.78%
# Risk Category: High Risk
# Interpretation: The analysis indicates a significant presence of abnormal tissue. Immediate consultation with a dermatologist is advised.
# --------------------------------------------------
# Image: ISIC_0001128_Segmentation.png
# Coverage Percentage: 43.70%
# Risk Category: High Risk
# Interpretation: The analysis indicates a significant presence of abnormal tissue. Immediate consultation with a dermatologist is advised.
# --------------------------------------------------
# Image: ISIC_0001427_Segmentation.png
# Coverage Percentage: 15.04%
# Risk Category: High Risk
# Interpretation: The analysis indicates a significant presence of abnormal tissue. Immediate consultation with a dermatologist is advised.
# --------------------------------------------------
# Image: ISIC_0001186_Segmentation.png
# Coverage Percentage: 9.67%
# Risk Category: Medium Risk
# Interpretation: The model has identified some regions of potential concern. It's recommended to consult a dermatologist for a more detailed examination.
# --------------------------------------------------
# Image: ISIC_0001484_Segmentation.png
# Coverage Percentage: 6.27%
# Risk Category: Medium Risk
# Interpretation: The model has identified some regions of potential concern. It's recommended to consult a dermatologist for a more detailed examination.
# --------------------------------------------------
# Image: ISIC_0002829_Segmentation.png
# Coverage Percentage: 19.24%
# Risk Category: High Risk
# Interpretation: The analysis indicates a significant presence of abnormal tissue. Immediate consultation with a dermatologist is advised.
# --------------------------------------------------
# Image: ISIC_0002107_Segmentation.png
# Coverage Percentage: 22.73%
# Risk Category: High Risk
# Interpretation: The analysis indicates a significant presence of abnormal tissue. Immediate consultation with a dermatologist is advised.
# --------------------------------------------------
# Image: ISIC_0001685_Segmentation.png
# Coverage Percentage: 10.64%
# Risk Category: Medium Risk
# Interpretation: The model has identified some regions of potential concern. It's recommended to consult a dermatologist for a more detailed examination.
# --------------------------------------------------
# Image: ISIC_0001960_Segmentation.png
# Coverage Percentage: 9.94%
# Risk Category: Medium Risk
# Interpretation: The model has identified some regions of potential concern. It's recommended to consult a dermatologist for a more detailed examination.
# --------------------------------------------------
# Image: ISIC_0002673_Segmentation.png
# Coverage Percentage: 9.55%
# Risk Category: Medium Risk
# Interpretation: The model has identified some regions of potential concern. It's recommended to consult a dermatologist for a more detailed examination.
# --------------------------------------------------
# Image: ISIC_0001103_Segmentation.png
# Coverage Percentage: 31.23%
# Risk Category: High Risk
# Interpretation: The analysis indicates a significant presence of abnormal tissue. Immediate consultation with a dermatologist is advised.
# --------------------------------------------------
# Image: ISIC_0001242_Segmentation.png
# Coverage Percentage: 29.17%
# Risk Category: High Risk
# Interpretation: The analysis indicates a significant presence of abnormal tissue. Immediate consultation with a dermatologist is advised.
# --------------------------------------------------
# Image: ISIC_0001100_Segmentation.png
# Coverage Percentage: 17.24%
# Risk Category: High Risk
# Interpretation: The analysis indicates a significant presence of abnormal tissue. Immediate consultation with a dermatologist is advised.
# --------------------------------------------------
# Image: ISIC_0002246_Segmentation.png
# Coverage Percentage: 11.89%
# Risk Category: Medium Risk
# Interpretation: The model has identified some regions of potential concern. It's recommended to consult a dermatologist for a more detailed examination.
# --------------------------------------------------
# Image: ISIC_0001299_Segmentation.png
# Coverage Percentage: 8.23%
# Risk Category: Medium Risk
# Interpretation: The model has identified some regions of potential concern. It's recommended to consult a dermatologist for a more detailed examination.
# --------------------------------------------------
# Image: ISIC_0001190_Segmentation.png
# Coverage Percentage: 2.22%
# Risk Category: Low Risk
# Interpretation: The analysis indicates a low presence of abnormal tissue. While it appears likely benign, always consider a professional dermatologist's advice.
# --------------------------------------------------
# Image: ISIC_0001181_Segmentation.png
# Coverage Percentage: 14.94%
# Risk Category: Medium Risk
# Interpretation: The model has identified some regions of potential concern. It's recommended to consult a dermatologist for a more detailed examination.
# --------------------------------------------------
# Image: ISIC_0001142_Segmentation.png
# Coverage Percentage: 54.81%
# Risk Category: High Risk
# Interpretation: The analysis indicates a significant presence of abnormal tissue. Immediate consultation with a dermatologist is advised.
# --------------------------------------------------
# Image: ISIC_0003056_Segmentation.png
# Coverage Percentage: 9.23%
# Risk Category: Medium Risk
# Interpretation: The model has identified some regions of potential concern. It's recommended to consult a dermatologist for a more detailed examination.
# --------------------------------------------------
# Image: ISIC_0006711_Segmentation.png
# Coverage Percentage: 5.42%
# Risk Category: Medium Risk
# Interpretation: The model has identified some regions of potential concern. It's recommended to consult a dermatologist for a more detailed examination.
# --------------------------------------------------
# Image: ISIC_0008116_Segmentation.png
# Coverage Percentage: 6.81%
# Risk Category: Medium Risk
# Interpretation: The model has identified some regions of potential concern. It's recommended to consult a dermatologist for a more detailed examination.
# --------------------------------------------------
# Image: ISIC_0004346_Segmentation.png
# Coverage Percentage: 3.71%
# Risk Category: Low Risk
# Interpretation: The analysis indicates a low presence of abnormal tissue. While it appears likely benign, always consider a professional dermatologist's advice.
# --------------------------------------------------
# Image: ISIC_0008406_Segmentation.png
# Coverage Percentage: 27.61%
# Risk Category: High Risk
# Interpretation: The analysis indicates a significant presence of abnormal tissue. Immediate consultation with a dermatologist is advised.
# --------------------------------------------------
# Image: ISIC_0005000_Segmentation.png
# Coverage Percentage: 3.15%
# Risk Category: Low Risk
# Interpretation: The analysis indicates a low presence of abnormal tissue. While it appears likely benign, always consider a professional dermatologist's advice.
# --------------------------------------------------
# Image: ISIC_0003559_Segmentation.png
# Coverage Percentage: 12.13%
# Risk Category: Medium Risk
# Interpretation: The model has identified some regions of potential concern. It's recommended to consult a dermatologist for a more detailed examination.
# --------------------------------------------------
# Image: ISIC_0008207_Segmentation.png
# Coverage Percentage: 8.23%
# Risk Category: Medium Risk
# Interpretation: The model has identified some regions of potential concern. It's recommended to consult a dermatologist for a more detailed examination.
# --------------------------------------------------
# Image: ISIC_0006193_Segmentation.png
# Coverage Percentage: 12.48%
# Risk Category: Medium Risk
# Interpretation: The model has identified some regions of potential concern. It's recommended to consult a dermatologist for a more detailed examination.
# --------------------------------------------------
# Image: ISIC_0004115_Segmentation.png
# Coverage Percentage: 6.79%
# Risk Category: Medium Risk
# Interpretation: The model has identified some regions of potential concern. It's recommended to consult a dermatologist for a more detailed examination.
# --------------------------------------------------
# Image: ISIC_0008507_Segmentation.png
# Coverage Percentage: 4.91%
# Risk Category: Low Risk
# Interpretation: The analysis indicates a low presence of abnormal tissue. While it appears likely benign, always consider a professional dermatologist's advice.
# --------------------------------------------------
# Image: ISIC_0003728_Segmentation.png
# Coverage Percentage: 5.71%
# Risk Category: Medium Risk
# Interpretation: The model has identified some regions of potential concern. It's recommended to consult a dermatologist for a more detailed examination.
# --------------------------------------------------
# Image: ISIC_0002871_Segmentation.png
# Coverage Percentage: 10.33%
# Risk Category: Medium Risk
# Interpretation: The model has identified some regions of potential concern. It's recommended to consult a dermatologist for a more detailed examination.
# --------------------------------------------------
# Image: ISIC_0007322_Segmentation.png
# Coverage Percentage: 7.54%
# Risk Category: Medium Risk
# Interpretation: The model has identified some regions of potential concern. It's recommended to consult a dermatologist for a more detailed examination.
# --------------------------------------------------
# Image: ISIC_0007693_Segmentation.png
# Coverage Percentage: 4.76%
# Risk Category: Low Risk
# Interpretation: The analysis indicates a low presence of abnormal tissue. While it appears likely benign, always consider a professional dermatologist's advice.
# --------------------------------------------------
# Image: ISIC_0008626_Segmentation.png
# Coverage Percentage: 18.36%
# Risk Category: High Risk
# Interpretation: The analysis indicates a significant presence of abnormal tissue. Immediate consultation with a dermatologist is advised.
# --------------------------------------------------
# Image: ISIC_0009889_Segmentation.png
# Coverage Percentage: 14.84%
# Risk Category: Medium Risk
# Interpretation: The model has identified some regions of potential concern. It's recommended to consult a dermatologist for a more detailed examination.
# --------------------------------------------------
# Image: ISIC_0009902_Segmentation.png
# Coverage Percentage: 26.44%
# Risk Category: High Risk
# Interpretation: The analysis indicates a significant presence of abnormal tissue. Immediate consultation with a dermatologist is advised.
# ...
# --------------------------------------------------
# Image: ISIC_0011162_Segmentation.png
# Coverage Percentage: 16.50%
# Risk Category: High Risk
# Interpretation: The analysis indicates a significant presence of abnormal tissue. Immediate consultation with a dermatologist is advised.
# --------------------------------------------------
# Image: ISIC_0011305_Segmentation.png
# Coverage Percentage: 8.25%
# Risk Category: Medium Risk
# Interpretation: The model has identified some regions of potential concern. It's recommended to consult a dermatologist for a more detailed examination.
# --------------------------------------------------
# Image: ISIC_0011171_Segmentation.png
# Coverage Percentage: 10.45%
# Risk Category: Medium Risk
# Interpretation: The model has identified some regions of potential concern. It's recommended to consult a dermatologist for a more detailed examination.
# --------------------------------------------------
# Image: ISIC_0011298_Segmentation.png
# Coverage Percentage: 9.08%
# Risk Category: Medium Risk
# Interpretation: The model has identified some regions of potential concern. It's recommended to consult a dermatologist for a more detailed examination.
# --------------------------------------------------
# Image: ISIC_0011101_Segmentation.png
# Coverage Percentage: 13.82%
# Risk Category: Medium Risk
# Interpretation: The model has identified some regions of potential concern. It's recommended to consult a dermatologist for a more detailed examination.
# --------------------------------------------------
# Image: ISIC_0011081_Segmentation.png
# Coverage Percentage: 34.94%
# Risk Category: High Risk
# Interpretation: The analysis indicates a significant presence of abnormal tissue. Immediate consultation with a dermatologist is advised.
# --------------------------------------------------
# Image: ISIC_0011080_Segmentation.png
# Coverage Percentage: 5.18%
# Risk Category: Medium Risk
# Interpretation: The model has identified some regions of potential concern. It's recommended to consult a dermatologist for a more detailed examination.
# --------------------------------------------------
# Image: ISIC_0011090_Segmentation.png
# Coverage Percentage: 30.86%
# Risk Category: High Risk
# Interpretation: The analysis indicates a significant presence of abnormal tissue. Immediate consultation with a dermatologist is advised.
# --------------------------------------------------
# Image: ISIC_0011104_Segmentation.png
# Coverage Percentage: 35.96%
# Risk Category: High Risk
# Interpretation: The analysis indicates a significant presence of abnormal tissue. Immediate consultation with a dermatologist is advised.
# --------------------------------------------------
# Image: ISIC_0011300_Segmentation.png
# Coverage Percentage: 22.34%
# Risk Category: High Risk
# Interpretation: The analysis indicates a significant presence of abnormal tissue. Immediate consultation with a dermatologist is advised.
# --------------------------------------------------
# Image: ISIC_0011098_Segmentation.png
# Coverage Percentage: 8.13%
# Risk Category: Medium Risk
# Interpretation: The model has identified some regions of potential concern. It's recommended to consult a dermatologist for a more detailed examination.
# --------------------------------------------------
# Image: ISIC_0011107_Segmentation.png
# Coverage Percentage: 18.43%
# Risk Category: High Risk
# Interpretation: The analysis indicates a significant presence of abnormal tissue. Immediate consultation with a dermatologist is advised.
# --------------------------------------------------
# Image: ISIC_0010863_Segmentation.png
# Coverage Percentage: 52.47%
# Risk Category: High Risk
# Interpretation: The analysis indicates a significant presence of abnormal tissue. Immediate consultation with a dermatologist is advised.
# --------------------------------------------------
# Image: ISIC_0011175_Segmentation.png
# Coverage Percentage: 36.77%
# Risk Category: High Risk
# Interpretation: The analysis indicates a significant presence of abnormal tissue. Immediate consultation with a dermatologist is advised.
# --------------------------------------------------
# Image: ISIC_0011219_Segmentation.png
# Coverage Percentage: 16.24%
# Risk Category: High Risk
# Interpretation: The analysis indicates a significant presence of abnormal tissue. Immediate consultation with a dermatologist is advised.
# --------------------------------------------------
# Image: ISIC_0011151_Segmentation.png
# Coverage Percentage: 59.99%
# Risk Category: High Risk
# Interpretation: The analysis indicates a significant presence of abnormal tissue. Immediate consultation with a dermatologist is advised.
# --------------------------------------------------
# Image: ISIC_0011122_Segmentation.png
# Coverage Percentage: 45.95%
# Risk Category: High Risk
# Interpretation: The analysis indicates a significant presence of abnormal tissue. Immediate consultation with a dermatologist is advised.
# --------------------------------------------------
# Image: ISIC_0011152_Segmentation.png
# Coverage Percentage: 3.98%
# Risk Category: Low Risk
# Interpretation: The analysis indicates a low presence of abnormal tissue. While it appears likely benign, always consider a professional dermatologist's advice.
# --------------------------------------------------
# Image: ISIC_0010856_Segmentation.png
# Coverage Percentage: 18.63%
# Risk Category: High Risk
# Interpretation: The analysis indicates a significant presence of abnormal tissue. Immediate consultation with a dermatologist is advised.
# --------------------------------------------------
# Image: ISIC_0011129_Segmentation.png
# Coverage Percentage: 38.40%
# Risk Category: High Risk
# Interpretation: The analysis indicates a significant presence of abnormal tissue. Immediate consultation with a dermatologist is advised.
# --------------------------------------------------
# Image: ISIC_0011172_Segmentation.png
# Coverage Percentage: 31.18%
# Risk Category: High Risk
# Interpretation: The analysis indicates a significant presence of abnormal tissue. Immediate consultation with a dermatologist is advised.
# --------------------------------------------------
# Image: ISIC_0011112_Segmentation.png
# Coverage Percentage: 55.00%
# Risk Category: High Risk
# Interpretation: The analysis indicates a significant presence of abnormal tissue. Immediate consultation with a dermatologist is advised.
# --------------------------------------------------
# Image: ISIC_0011092_Segmentation.png
# Coverage Percentage: 8.08%
# Risk Category: Medium Risk
# Interpretation: The model has identified some regions of potential concern. It's recommended to consult a dermatologist for a more detailed examination.
# --------------------------------------------------
# Image: ISIC_0011294_Segmentation.png
# Coverage Percentage: 20.80%
# Risk Category: High Risk
# Interpretation: The analysis indicates a significant presence of abnormal tissue. Immediate consultation with a dermatologist is advised.
# --------------------------------------------------
# Image: ISIC_0011132_Segmentation.png
# Coverage Percentage: 13.35%
# Risk Category: Medium Risk
# Interpretation: The model has identified some regions of potential concern. It's recommended to consult a dermatologist for a more detailed examination.
# --------------------------------------------------
# Image: ISIC_0011224_Segmentation.png
# Coverage Percentage: 21.04%
# Risk Category: High Risk
# Interpretation: The analysis indicates a significant presence of abnormal tissue. Immediate consultation with a dermatologist is advised.
# --------------------------------------------------
# Image: ISIC_0011155_Segmentation.png
# Coverage Percentage: 29.42%
# Risk Category: High Risk
# Interpretation: The analysis indicates a significant presence of abnormal tissue. Immediate consultation with a dermatologist is advised.
# --------------------------------------------------
# Image: ISIC_0011089_Segmentation.png
# Coverage Percentage: 19.87%
# Risk Category: High Risk
# Interpretation: The analysis indicates a significant presence of abnormal tissue. Immediate consultation with a dermatologist is advised.
# --------------------------------------------------
# Image: ISIC_0011177_Segmentation.png
# Coverage Percentage: 40.26%
# Risk Category: High Risk
# Interpretation: The analysis indicates a significant presence of abnormal tissue. Immediate consultation with a dermatologist is advised.
# --------------------------------------------------
# Image: ISIC_0011292_Segmentation.png
# Coverage Percentage: 13.82%
# Risk Category: Medium Risk
# Interpretation: The model has identified some regions of potential concern. It's recommended to consult a dermatologist for a more detailed examination.
# --------------------------------------------------
# Image: ISIC_0011143_Segmentation.png
# Coverage Percentage: 0.00%
# Risk Category: Low Risk
# Interpretation: The analysis indicates a low presence of abnormal tissue. While it appears likely benign, always consider a professional dermatologist's advice.
# --------------------------------------------------
# Image: ISIC_0011110_Segmentation.png
# Coverage Percentage: 20.12%
# Risk Category: High Risk
# Interpretation: The analysis indicates a significant presence of abnormal tissue. Immediate consultation with a dermatologist is advised.
# --------------------------------------------------
# Image: ISIC_0011176_Segmentation.png
# Coverage Percentage: 23.05%
# Risk Category: High Risk
# Interpretation: The analysis indicates a significant presence of abnormal tissue. Immediate consultation with a dermatologist is advised.
# --------------------------------------------------
# Image: ISIC_0011168_Segmentation.png
# Coverage Percentage: 9.08%
# Risk Category: Medium Risk
# Interpretation: The model has identified some regions of potential concern. It's recommended to consult a dermatologist for a more detailed examination.
# --------------------------------------------------
# Image: ISIC_0011227_Segmentation.png
# Coverage Percentage: 44.31%
# Risk Category: High Risk
# Interpretation: The analysis indicates a significant presence of abnormal tissue. Immediate consultation with a dermatologist is advised.
# --------------------------------------------------
# Image: ISIC_0011148_Segmentation.png
# Coverage Percentage: 26.71%
# Risk Category: High Risk
# Interpretation: The analysis indicates a significant presence of abnormal tissue. Immediate consultation with a dermatologist is advised.
# --------------------------------------------------
# Image: ISIC_0011083_Segmentation.png
# Coverage Percentage: 0.00%
# Risk Category: Low Risk
# Interpretation: The analysis indicates a low presence of abnormal tissue. While it appears likely benign, always consider a professional dermatologist's advice.
# --------------------------------------------------
# Image: ISIC_0011149_Segmentation.png
# Coverage Percentage: 62.35%
# Risk Category: High Risk
# Interpretation: The analysis indicates a significant presence of abnormal tissue. Immediate consultation with a dermatologist is advised.
# --------------------------------------------------
# Image: ISIC_0011205_Segmentation.png
# Coverage Percentage: 11.87%
# Risk Category: Medium Risk
# Interpretation: The model has identified some regions of potential concern. It's recommended to consult a dermatologist for a more detailed examination.
# --------------------------------------------------
# Image: ISIC_0011150_Segmentation.png
# Coverage Percentage: 8.98%
# Risk Category: Medium Risk
# Interpretation: The model has identified some regions of potential concern. It's recommended to consult a dermatologist for a more detailed examination.
# --------------------------------------------------
# Image: ISIC_0011344_Segmentation.png
# Coverage Percentage: 0.49%
# Risk Category: Low Risk
# Interpretation: The analysis indicates a low presence of abnormal tissue. While it appears likely benign, always consider a professional dermatologist's advice.
# --------------------------------------------------
# Image: ISIC_0011384_Segmentation.png
# Coverage Percentage: 25.07%
# Risk Category: High Risk
# Interpretation: The analysis indicates a significant presence of abnormal tissue. Immediate consultation with a dermatologist is advised.
# --------------------------------------------------
# Image: ISIC_0011336_Segmentation.png
# Coverage Percentage: 43.29%
# Risk Category: High Risk
# Interpretation: The analysis indicates a significant presence of abnormal tissue. Immediate consultation with a dermatologist is advised.
# --------------------------------------------------
# Image: ISIC_0011359_Segmentation.png
# Coverage Percentage: 23.97%
# Risk Category: High Risk
# Interpretation: The analysis indicates a significant presence of abnormal tissue. Immediate consultation with a dermatologist is advised.
# --------------------------------------------------
# Image: ISIC_0011386_Segmentation.png
# Coverage Percentage: 8.89%
# Risk Category: Medium Risk
# Interpretation: The model has identified some regions of potential concern. It's recommended to consult a dermatologist for a more detailed examination.
# --------------------------------------------------
# Image: ISIC_0011367_Segmentation.png
# Coverage Percentage: 3.27%
# Risk Category: Low Risk
# Interpretation: The analysis indicates a low presence of abnormal tissue. While it appears likely benign, always consider a professional dermatologist's advice.
# --------------------------------------------------
# Image: ISIC_0011333_Segmentation.png
# Coverage Percentage: 42.24%
# Risk Category: High Risk
# Interpretation: The analysis indicates a significant presence of abnormal tissue. Immediate consultation with a dermatologist is advised.
# --------------------------------------------------
# Image: ISIC_0011319_Segmentation.png
# Coverage Percentage: 19.82%
# Risk Category: High Risk
# Interpretation: The analysis indicates a significant presence of abnormal tissue. Immediate consultation with a dermatologist is advised.
# --------------------------------------------------
# Image: ISIC_0011338_Segmentation.png
# Coverage Percentage: 36.87%
# Risk Category: High Risk
# Interpretation: The analysis indicates a significant presence of abnormal tissue. Immediate consultation with a dermatologist is advised.
# --------------------------------------------------
# Image: ISIC_0011349_Segmentation.png
# Coverage Percentage: 66.41%
# Risk Category: High Risk
# Interpretation: The analysis indicates a significant presence of abnormal tissue. Immediate consultation with a dermatologist is advised.
# --------------------------------------------------
# Image: ISIC_0011325_Segmentation.png
# Coverage Percentage: 36.65%
# Risk Category: High Risk
# Interpretation: The analysis indicates a significant presence of abnormal tissue. Immediate consultation with a dermatologist is advised.
# --------------------------------------------------
# Image: ISIC_0011392_Segmentation.png
# Coverage Percentage: 25.73%
# Risk Category: High Risk
# Interpretation: The analysis indicates a significant presence of abnormal tissue. Immediate consultation with a dermatologist is advised.
# --------------------------------------------------
# Image: ISIC_0011310_Segmentation.png
# Coverage Percentage: 29.61%
# Risk Category: High Risk
# Interpretation: The analysis indicates a significant presence of abnormal tissue. Immediate consultation with a dermatologist is advised.
# --------------------------------------------------
# Image: ISIC_0011363_Segmentation.png
# Coverage Percentage: 21.61%
# Risk Category: High Risk
# Interpretation: The analysis indicates a significant presence of abnormal tissue. Immediate consultation with a dermatologist is advised.
# --------------------------------------------------
# Image: ISIC_0011374_Segmentation.png
# Coverage Percentage: 44.63%
# Risk Category: High Risk
# Interpretation: The analysis indicates a significant presence of abnormal tissue. Immediate consultation with a dermatologist is advised.
# --------------------------------------------------
# Image: ISIC_0011321_Segmentation.png
# Coverage Percentage: 16.31%
# Risk Category: High Risk
# Interpretation: The analysis indicates a significant presence of abnormal tissue. Immediate consultation with a dermatologist is advised.
# --------------------------------------------------
